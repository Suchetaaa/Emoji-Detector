# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset-fb-valence-arousal-anon.csv")

# %%
df
# Out:
#                                      Anonymized Message  Valence1  Valence2  \
# 0     We'll be off and running to a lil' place calle...         9         9
# 1                              I really wana move soon!         4         5
# 2                               thinking at charity cup         5         5
# 3     thinks that for girls, boys are easily found. ...         4         3
# 4                    Our Wedding Anniversary tonight...         7         7
# 5            Just sip some crystal with these real ones         5         5
# 6     Believe The Hype for Raleigh! Snip3down is goi...         6         8
# 7     I would like to thank all of my family and fri...         8         9
# 8     Holy shit... Still playing with go to meeting....         3         5
# 9                         So happy <PERSON> is the bomb         6         8
# 10                getting ready for the big move people         7         5
# ...

# %%
vec1 = df['Anonymized Message']
vec2 = df['Valence1']
vec3 = df['Valence2']
vec4 = df['Arousal1']
vec5 = df['Arousal2']
